# %%
import numpy as np
import matplotlib.pylab as plt
import os
os.environ["CDF_LIB"] = 'lib_copy'
from spacepy import pycdf
import cdflib

# %%
cdf = pycdf.CDF("psp_fld_l2_mag_RTN_1min_20211001_v00.cdf")
with pycdf.CDF('psp_fld_l2_mag_RTN_1min_20211001_v00.cdf') as cdf:
    data = cdf.copy()


# print(cdf)
# print(data)
data.keys()
# Out:
# dict_keys(['epoch_mag_RTN_1min', 'psp_fld_l2_mag_RTN_1min', 'label_RTN', 'component_index_RTN', 'epoch_quality_flags', 'psp_fld_l2_quality_flags'])

# %%
print(data['psp_fld_l2_mag_RTN_1min'])
# Out:
# [[ 0.7969783 -3.6009414  0.8622658]
#  [ 0.8009241 -3.5137916  0.6711523]
#  [ 0.7299848 -3.444862   0.602647 ]
#  ...
#  [-1.4215373 -6.834241  -2.46465  ]
#  [-1.2149973 -6.723606  -2.7118773]
#  [-1.169563  -6.8570333 -2.484532 ]]

# %%
plt.plot(data['epoch_mag_RTN_1min'], data['psp_fld_l2_mag_RTN_1min'])

# c= data['psp_fld_l2_mag_RTN_1min']
# c1 =c[:,0]
# c2 =c[:,1]
# c3 =c[:,2]

# plt.plot(data['epoch_mag_RTN_1min'], c1+2,'blue')
# plt.plot(data['epoch_mag_RTN_1min'], c2+1,'orange')
# plt.plot(data['epoch_mag_RTN_1min'], c3+2, 'green')
